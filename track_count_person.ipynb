# %%
from ultralytics import YOLO

import time
import torch
import cv2
import torch.backends.cudnn as cudnn
from PIL import Image
import colorsys
import numpy as np

# %%
from deep_sort.utils.parser import get_config
from deep_sort.deep_sort import DeepSort
from deep_sort.sort.tracker import Tracker

deep_sort_weights = 'deep_sort/deep/checkpoint/ckpt.t7'
tracker = DeepSort(model_path=deep_sort_weights, max_age=70)

# %%
# Define the video path
import cv2
import torch


video_path = 'input_videos\Surveillance_ Thieves rip open ATM in Shelbyville.mp4'

cap = cv2.VideoCapture(video_path)

# Get the video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
output_path = 'output.mp4'
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\S'
# <>:6: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\drums\AppData\Local\Temp\ipykernel_6484\542052414.py:6: SyntaxWarning: invalid escape sequence '\S'
#   video_path = 'input_videos\Surveillance_ Thieves rip open ATM in Shelbyville.mp4'

# %%
frames = []

unique_track_ids = set()

# %%
import cv2
import numpy as np
import time

# Initialize the YOLO model
model = YOLO("yolov8n.pt")  # Load the model once before the loop

# Open the webcam
cap = cv2.VideoCapture(0)  # 0 is the default camera, change if needed

# Initialize variables
counter, fps, elapsed = 0, 0, 0
start_time = time.perf_counter()
unique_track_ids = set()
track_labels = {}
track_times = {}
fps = cap.get(cv2.CAP_PROP_FPS)  # Get the frame rate of the video

while cap.isOpened():
    ret, frame = cap.read()

    if ret:
        # Flip the frame horizontally to correct the mirrored effect
        frame = cv2.flip(frame, 1)

        og_frame = frame
        frame = og_frame.copy()

        results = model(frame, device=0, classes=0, conf=0.5)

        class_names = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

        active_track_ids = set()

        for result in results:
            boxes = result.boxes
            cls = boxes.cls.tolist()
            xyxy = boxes.xyxy
            conf = boxes.conf
            xywh = boxes.xywh

            for class_index in cls:
                class_name = class_names[int(class_index)]
                print("Class:", class_name)

        pred_cls = np.array(cls)
        conf = conf.detach().cpu().numpy()
        xyxy = xyxy.detach().cpu().numpy()
        bboxes_xywh = xywh.cpu().numpy()

        tracks = tracker.update(bboxes_xywh, conf, og_frame)

        for track in tracker.tracker.tracks:
            track_id = track.track_id
            hits = track.hits
            x1, y1, x2, y2 = track.to_tlbr()
            w = x2 - x1
            h = y2 - y1

            red_color = (0, 0, 255)
            blue_color = (255, 0, 0)
            green_color = (0, 255, 0)

            color_id = track_id % 3
            color = red_color if color_id == 0 else blue_color if color_id == 1 else green_color

            cv2.rectangle(og_frame, (int(x1), int(y1)), (int(x1 + w), int(y1 + h)), color, 2)

            # Track the label and start time for the detected object
            if track_id not in track_labels:
                track_labels[track_id] = class_names[int(cls[0])]  # Assuming each track belongs to one class
                track_times[track_id] = 0  # Initialize the time spent

            # Update the time spent (in frames)
            track_times[track_id] += 1

            # Calculate time spent in minutes and seconds
            total_seconds = track_times[track_id] / fps
            minutes = int(total_seconds // 60)
            seconds = int(total_seconds % 60)

            text_color = (0, 0, 0)
            cv2.putText(og_frame, f"{track_labels[track_id]} {minutes:02}:{seconds:02}", 
                        (int(x1) + 10, int(y1) - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)

            active_track_ids.add(track_id)

        lost_track_ids = unique_track_ids - active_track_ids
        for lost_track_id in lost_track_ids:
            track_labels.pop(lost_track_id, None)
            track_times.pop(lost_track_id, None)

        unique_track_ids.intersection_update(active_track_ids)
        unique_track_ids.update(active_track_ids)

        person_count = len(unique_track_ids)

        current_time = time.perf_counter()
        elapsed = (current_time - start_time)
        counter += 1
        if elapsed > 1:
            fps = counter / elapsed
            counter = 0
            start_time = current_time

        cv2.putText(og_frame, f"Person Count: {person_count}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.namedWindow("Video", cv2.WINDOW_NORMAL)
        cv2.resizeWindow("Video", 960, 540)
        cv2.imshow("Video", og_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 71.2ms
# Speed: 16.1ms preprocess, 71.2ms inference, 79.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.7ms
# Speed: 7.5ms preprocess, 55.7ms inference, 337.6ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 56.8ms
# Speed: 15.9ms preprocess, 56.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 72.8ms
# Speed: 0.0ms preprocess, 72.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 15.4ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 (no detections), 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.6ms
# Speed: 0.0ms preprocess, 22.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.8ms
# Speed: 0.0ms preprocess, 19.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.6ms
# Speed: 3.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.7ms
# Speed: 0.0ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 18.5ms
# Speed: 0.0ms preprocess, 18.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 14.3ms
# Speed: 0.0ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 23.1ms
# Speed: 0.0ms preprocess, 23.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 22.2ms
# Speed: 0.0ms preprocess, 22.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 (no detections), 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.2ms
# Speed: 5.2ms preprocess, 14.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 (no detections), 23.9ms
# Speed: 0.0ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 11.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 24.7ms
# Speed: 0.0ms preprocess, 24.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 20.8ms
# Speed: 1.8ms preprocess, 20.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.1ms
# Speed: 0.0ms preprocess, 19.1ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 (no detections), 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 10.7ms
# Speed: 4.7ms preprocess, 10.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 25.5ms
# Speed: 0.0ms preprocess, 25.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 (no detections), 18.5ms
# Speed: 0.0ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 28.9ms
# Speed: 0.0ms preprocess, 28.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.9ms
# Speed: 0.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 0.0ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 13.4ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 24.6ms
# Speed: 4.6ms preprocess, 24.6ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person,
6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 12.1ms
# Speed: 3.8ms preprocess, 12.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 58.8ms
# Speed: 0.0ms preprocess, 58.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 8.6ms
# Speed: 0.0ms preprocess, 8.6ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 9.1ms
# Speed: 0.2ms preprocess, 9.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.8ms
# Speed: 0.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 17.3ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 41.5ms
# Speed: 6.2ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.9ms
# Speed: 0.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.7ms
# Speed: 0.0ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 41.9ms
# Speed: 0.0ms preprocess, 41.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 11.3ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 22.2ms
# Speed: 0.4ms preprocess, 22.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.4ms
# Speed: 5.1ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.4ms
# Speed: 2.8ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 2 persons, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 19.5ms
# Speed: 3.7ms preprocess, 19.5ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 1 person, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.9ms
# Speed: 3.3ms preprocess, 16.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 24.6ms
# Speed: 0.0ms preprocess, 24.6ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 10.4ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 14.2ms
# Speed: 3.4ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 27.4ms
# Speed: 0.0ms preprocess, 27.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 22.6ms
# Speed: 0.0ms preprocess, 22.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.2ms
# Speed: 0.0ms preprocess, 11.2ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.0ms preprocess, 21.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 26.3ms
# Speed: 0.0ms preprocess, 26.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 2 persons, 18.2ms
# Speed: 0.0ms preprocess, 18.2ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 (no detections), 30.7ms
# Speed: 0.0ms preprocess, 30.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 19.9ms
# Speed: 0.0ms preprocess, 19.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 25.6ms
# Speed: 0.0ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 29.1ms
# Speed: 0.0ms preprocess, 29.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 1 person, 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 2 persons, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 1 person, 9.7ms
# Speed: 0.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 (no detections), 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.1ms
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 23.2ms
# Speed: 0.5ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 (no detections), 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 2 persons, 12.7ms
# Speed: 0.0ms preprocess, 12.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 1 person, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 24.2ms
# Speed: 0.0ms preprocess, 24.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 2 persons, 17.2ms
# Speed: 3.2ms preprocess, 17.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
# Class: person
#
# 0: 480x640 1 person, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 29.0ms
# Speed: 0.0ms preprocess, 29.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.0ms
# Speed: 0.0ms preprocess, 19.0ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 21.2ms
# Speed: 0.0ms preprocess, 21.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 25.5ms
# Speed: 0.0ms preprocess, 25.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 28.2ms
# Speed: 0.0ms preprocess, 28.2ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 12.1ms
# Speed: 0.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 22.5ms
# Speed: 0.0ms preprocess, 22.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.9ms
# Speed: 2.9ms preprocess, 17.9ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.9ms
# Speed: 0.0ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 7.9ms
# Speed: 3.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 19.1ms
# Speed: 0.5ms preprocess, 19.1ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 26.8ms
# Speed: 0.0ms preprocess, 26.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.0ms preprocess, 21.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: person
